# %%
#1. Why are functions advantageous to have in your programs?
The main purpose of function is write once and run anytime.
There are many advantages of using function in python

1. Code reusability
2. Write once and run anytime
3. It must return value'
4. Instead of writing same code many time we need to call the function to accomplish the task for you.
5. When writing a number of statement inside a block and whcih can be executed in a sequential manner then that single unit is
called as function.

#2. When does the code in a function run: when it's specified or when it's called?

Inorder to execute the function we need to call the function by its name either by passing parameter or without arguments.
Simply specifiying the function it won't work for us. we need to call it.

#3. What statement creates a function?

To create a function in python we need to use a key word def in python
the syntx to create a function is

def Function_name(argument, or no argument):
    statement(s)

Function_name(argument, or no argument)

# 4. What is the difference between a function and a function call?

Function:- It a group of statements that are kept as a single unit with a name is known as function and can be executed by calling it's name

Function call:- Inorder the function to run we need to call the function by it's name is known as function call and we call a function inside another function

# 5. How many global scopes are there in a Python program? How many local scopes?

There are as many global scopes are availble in python programs but we have only1 local scope as, the accessibility of the variables inside
a function is limited to itself

def func1(test):
    x=99
    print(x)
def func2(test1):
    print(x)

func1(1)
func2(2)--There won't get any output rather than erro as the scope is inside the func1 s it's scope is limited to local only

The scope of the global varibale is accessible through out the function and accross all the written functions
x=99
def f1():
    print(x)
def f2():
    print(x)

f1()
f2()


# 6. What happens to variables in a local scope when the function call returns?

The variable in local scope gets accessed when a function call returns by it's name.

# 7. What is the concept of a return value? Is it possible to have a return value in an expression?

When we call  a function it must return a value where as in an expression it may not return a value when it's executed .
Bydefault the system has return None as output.

#8. If a function does not have a return statement, what is the return value of a call to that function?

If a function does not have a return statement then bydefault it will return None

#9. How do you make a function variable refer to the global variable?

When we define a variable as a global scope inside a class and can be accessed by all the defined functions in the class.

eg:-
    global test=99

In this way the varibale can be made global.

#10. What is the data type of None?

The Data type of None is NoneType

# 11. What does the sentence import areallyourpetsnamederic do?

That import statement imports a module named areallyourpetsnamederic.

# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?


here we can call the function bacon() function after importing the spam module

from spam import bacon()

13. What can you do to save a programme from crashing if it encounters an error?

The programme can be saved from crashing on encountering the error by sending the control to except block
on skipping the code in between.we have to move our code inside a try and except statement.
if we will run the code then it will not through the error instead of error message.

# 14. What is the purpose of the try clause? What is the purpose of the except clause?

The purpose of try clause is to capture the unwanted error occured while running the code and the piece of programme is sent to except 
block which will handle the error. It will display the error message instead of error on the console.
